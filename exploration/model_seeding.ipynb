# %%
# Import Libraries
import pandas as pd

# Import Seeding
pd.read_csv("../data/cbbdata/ncaa_sheets.csv").reset_index(drop = True)
# Out:
#      rank                    team  seed  net kpi_resume sor_resume avg_resume  \
# 0       1                Virginia   1.0    1          2          1        1.5
# 1       2                 Gonzaga   1.0    2         11          9         10
# 2       3                    Duke   1.0    3          1          2        1.5
# 3       4                 Houston   3.0    4          5         11          8
# 4       5               Tennessee   2.0    5         10          4          7
# ...   ...                     ...   ...  ...        ...        ...        ...
# 1808  358              Lindenwood   NaN  358        349        350      349.5
# 1809  359                 Detroit   NaN  359        352        358        355
# 1810  360              Coppin St.   NaN  360        363        357        360
# 1811  361                   IUPUI   NaN  361        353        351        352
# 1812  362  Mississippi Valley St.   NaN  362        361        359        360
#
# ...
