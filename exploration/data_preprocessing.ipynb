# %% [markdown]
# Import Libraries & Data

# %%
#Import Packages

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.style.use('ggplot')
import seaborn as sns
# Out:
#      Unnamed: 0  team_id abbreviation                display_name  \
# 0             1     2000          ACU  Abilene Christian Wildcats
# 1             2     2005          AFA           Air Force Falcons
# 2             3     2006          AKR                  Akron Zips
# 3             4     2010         AAMU        Alabama A&M Bulldogs
# 4             5      333          ALA        Alabama Crimson Tide
# ..          ...      ...          ...                         ...
# 355         356     2750         WRST        Wright State Raiders
# 356         357     2751          WYO             Wyoming Cowboys
# 357         358     2752          XAV           Xavier Musketeers
# 358         359       43         YALE               Yale Bulldogs
# 359         360     2754          YSU   Youngstown State Penguins
#
#          short_name        mascot        nickname               team   color  \
# 0    Abilene Chrstn      Wildcats  Abilene Chrstn  Abilene Christian  4e2683
# 1         Air Force       Falcons       Air Force          Air Force  004a7b
# 2             Akron          Zips           Akron              Akron  00285e
# 3       Alabama A&M      Bulldogs     Alabama A&M        Alabama A&M  790000
# 4           Alabama  Crimson Tide         Alabama            Alabama  690014
# ..              ...           ...             ...                ...     ...
# 355       Wright St       Raiders       Wright St       Wright State  cba052
# 356         Wyoming       Cowboys         Wyoming            Wyoming  533B22
# 357          Xavier    Musketeers          Xavier             Xavier  002144
# 358            Yale      Bulldogs            Yale               Yale  004a81
# 359   Youngstown St      Penguins   Youngstown St   Youngstown State  E51935
#
#     alternate_color                                               logo  \
# 0            ebebeb  https://a.espncdn.com/i/teamlogos/ncaa/500/200...
# 1            ffffff  https://a.espncdn.com/i/teamlogos/ncaa/500/200...
# 2            84754e  https://a.espncdn.com/i/teamlogos/ncaa/500/200...
# 3            ffffff  https://a.espncdn.com/i/teamlogos/ncaa/500/201...
# 4            f1f2f3  https://a.espncdn.com/i/teamlogos/ncaa/500/333...
# ..              ...                                                ...
# 355          cba052  https://a.espncdn.com/i/teamlogos/ncaa/500/275...
# 356          ffffff  https://a.espncdn.com/i/teamlogos/ncaa/500/275...
# 357          9ea2a2  https://a.espncdn.com/i/teamlogos/ncaa/500/275...
# 358          286dc0  https://a.espncdn.com/i/teamlogos/ncaa/500/43.png
# 359          690717  https://a.espncdn.com/i/teamlogos/ncaa/500/275...
#
#                                              logo_dark
# 0    https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 1    https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 2    https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 3    https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 4    https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# ..                                                 ...
# 355  https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 356  https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 357  https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 358  https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
# 359  https://a.espncdn.com/i/teamlogos/ncaa/500-dar...
#
# [360 rows x 12 columns]

# %%
# Import Data

teams = pd.read_csv("../data/teams.csv")
hist = pd.read_csv("../data/NCAA_Tourney_2002_2023.csv")

# %% [markdown]
# Correlation Matrix

# %%
#Examine

# %%
#Drop Highly Correlated

# %% [markdown]
# Feature Scaling

# %%
#
