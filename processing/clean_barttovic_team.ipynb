# %%
# Import Packages
import re
import pandas as pd

def clean_barttovic_team(df: pd.DataFrame):
    df.columns = df.iloc[1]
    df = df.iloc[2:, 1:]
    return df
    
clean_barttovic_team(pd.read_csv("C:/Users/Peter/AppData/Local/GitHubDesktop/app-2.9.6/The_Perfect_Bracket/data/barttovic/Houston/barttovic_Houston_2008.csv")).head(100)
# Out:
# 1                Category Offense   Defense      Barthag     NaN         NaN  \
# 2               Adj. Eff.   112.7        34        100.8     153       .7822
# 3                    eFG%    49.8       172         49.1     130         NaN
# 4                     TO%    15.4         3         22.7      77         NaN
# 5                     OR%    31.7       215         33.4     196         NaN
# 6                     FTR    33.5       250         38.8     212         NaN
# ..                    ...     ...       ...          ...     ...         ...
# 66  Postseason Tournament     NaN       NaN          NaN     NaN         NaN
# 67         Tue 3-18\n3-18       A       NaN      108 (Ⅱ)     NaN      Nevada
# 68         Mon 3-24\n3-24       H       NaN      124 (Ⅱ)     NaN  Valparaiso
# 69         Wed 3-26\n3-26       A       NaN       72 (Ⅱ)     NaN       Tulsa
# 70                   Date     NaN  Opponent  Result/Line  Record         WAB
#
# ...
